# %%
from pywinauto.application import Application
from pywinauto import Desktop
import time

OPTV_PATH = r"C:\Electromind\OPTV Logger\OPTV.exe"
BHTV_PATH = r"C:\Electromind\BHTV Logger\BHTV.exe"

# %%
app = Application(backend="uia").start(OPTV_PATH)

# %%
app.OPTV.OK.click()
# Out:
# <uia_controls.ButtonWrapper - '', None, 5810904847186171757>

# %%
main = app.window(title_re=".*OPTV Acquisition.*")
main.set_focus()
print(main.window_text())
# Out:
# OPTV Acquisition software version 2.00

# %%
main.type_keys("%f")       # Alt + F, open File menu
time.sleep(0.1)

main.type_keys("x") # move to Export
time.sleep(0.1)

main.type_keys("p")  # open Export submenu
time.sleep(0.1)

#main.type_keys("{DOWN 2}")   # move from Picture to LAS File
#time.sleep(0.2)

# %%
dialog = Desktop(backend="win32").window(title_re=".*Picture export.*")
dialog.wait("visible", timeout=10)
dialog.set_focus()

print(dialog.window_text())
# Out:
# Picture export

# %%
dialog.print_control_identifiers()
# Out:
# Control Identifiers:
#
# Dialog - 'Picture export'    (L673, T361, R1267, B939)
# ['Dialog', 'Picture export', 'Picture exportDialog']
# child_window(title="Picture export", class_name="#32770")
#    |
#    | GroupBox - 'Input file'    (L943, T392, R1257, B449)
#    | ['Input file', 'Input fileGroupBox', 'GroupBox', 'GroupBox0', 'GroupBox1']
#    | child_window(title="Input file", class_name="Button")
#    |
#    | Static - 'C:\2026_RTIO\West Angelas\Sent\GR26WAH0001\OTV\GR26WAH0001_OBI_INRUN.lox'    (L970, T416, R1204, B437)
#    | ['Static', 'C:\\2026_RTIO\\West Angelas\\Sent\\GR26WAH0001\\OTV\\GR26WAH0001_OBI_INRUN.loxStatic', 'C:\\2026_RTIO\\West Angelas\\Sent\\GR26WAH0001\\OTV\\GR26WAH0001_OBI_INRUN.lox', 'Static0', 'Static1']
#    | child_window(title="C:\2026_RTIO\West Angelas\Sent\GR26WAH0001\OTV\GR26WAH0001_OBI_INRUN.lox", class_name="Static")
#    |
#    | CheckBox - '&Reverse depth'    (L1161, T398, R1257, B413)
#    | ['&Reverse depthCheckBox', 'CheckBox', '&Reverse depth', 'CheckBox0', 'CheckBox1']
#    | child_window(title="&Reverse depth", class_name="Button")
#    |
#    | Button - '...'    (L1204, T416, R1224, B436)
#    | ['...Button', '...', 'Button', '...Button0', '...Button1', '...0', '...1', 'Button0', 'Button1']
#    | child_window(title="...", class_name="Button")
#    |
#    | GroupBox - 'Export depth range'    (L942, T449, R1257, B550)
#    | ['Export depth range', 'GroupBox2', 'Export depth rangeGroupBox']
#    | child_window(title="Export depth range", class_name="Button")
#    |
#    | Static - '&From'    (L961, T472, R991, B485)
#    | ['Static2', '&FromStatic', '&From']
#    | child_window(title="&From", class_name="Static")
#    |
#    | Edit - '1.48'    (L991, T468, R1065, B488)
#    | ['&FromEdit', 'Edit', 'Edit0', 'Edit1']
#    | child_window(title="1.48", class_name="Edit")
#    |
#    | Static - 'm'    (L1069, T472, R1081, B485)
#    | ['m', 'Static3', 'mStatic', 'm0', 'm1', 'mStatic0', 'mStatic1']
#    | child_window(title="m", class_name="Static")
#    |
#    | Static - '&To'    (L1123, T472, R1140, B485)
#    | ['Static4', '&To', '&ToStatic']
#    | child_window(title="&To", class_name="Static")
#    |
#    | Edit - '50.90'    (L1146, T468, R1220, B488)
#    | ['&ToEdit', 'Edit2']
#    | child_window(title="50.90", class_name="Edit")
#    |
#    | Static - 'Average source file depth sampling :'    (L976, T499, R1153, B512)
#    | ['Static5', 'Average source file depth sampling :Static', 'Average source file depth sampling :']
#    | child_window(title="Average source file depth sampling :", class_name="Static")
#    |
#    | Static - '1.75'    (L1159, T499, R1186, B512)
#    | ['1.75', 'Static6', '1.75Static']
#    | child_window(title="1.75", class_name="Static")
#    |
#    | Static - 'mm'    (L1192, T499, R1210, B512)
#    | ['mmStatic', 'Static7', 'mm', 'mmStatic0', 'mmStatic1', 'mm0', 'mm1']
#    | child_window(title="mm", class_name="Static")
#    |
#    | Static - 'Depth sampling interval'    (L969, T527, R1083, B540)
#    | ['Static8', 'Depth sampling intervalStatic', 'Depth sampling interval']
#    | child_window(title="Depth sampling interval", class_name="Static")
#    |
#    | ComboBox - '2.0'    (L1095, T522, R1139, B543)
#    | ['Depth sampling intervalComboBox', 'ComboBox', 'ComboBox0', 'ComboBox1']
#    | child_window(title="2.0", class_name="ComboBox")
#    |
#    | Static - 'mm'    (L1147, T525, R1165, B538)
#    | ['mmStatic2', 'Static9', 'mm2']
#    | child_window(title="mm", class_name="Static")
#    |
#    | Static - '(0.9 - 8.8)'    (L1174, T525, R1242, B538)
#    | ['Static10', '(0.9 - 8.8)', '(0.9 - 8.8)Static']
#    | child_window(title="(0.9 - 8.8)", class_name="Static")
#    |
#    | Edit - '1.8'    (L1089, T522, R1143, B542)
#    | ['Depth sampling intervalEdit', 'Edit3']
#    | child_window(title="1.8", class_name="Edit")
#    |
#    | GroupBox - 'Deviation'    (L943, T550, R1132, B594)
#    | ['GroupBox3', 'DeviationGroupBox', 'Deviation']
#    | child_window(title="Deviation", class_name="Button")
#    |
#    | Static - 'Use'    (L955, T567, R976, B580)
#    | ['Use', 'Static11', 'UseStatic']
#    | child_window(title="Use", class_name="Static")
#    |
#    | ComboBox - 'Magnetic North'    (L982, T564, R1120, B585)
#    | ['ComboBox2', 'UseComboBox']
#    | child_window(title="Magnetic North", class_name="ComboBox")
#    |
#    | GroupBox - 'Max of lines'    (L1138, T550, R1257, B594)
#    | ['Max of lines', 'GroupBox4', 'Max of linesGroupBox']
#    | child_window(title="Max of lines", class_name="Button")
#    |
#    | Edit - '25600'    (L1144, T566, R1197, B586)
#    | ['DeviationEdit', 'Edit4']
#    | child_window(title="25600", class_name="Edit")
#    |
#    | Static - '46.080 m'    (L1203, T569, R1253, B584)
#    | ['Static12', '46.080 mStatic', '46.080 m']
#    | child_window(title="46.080 m", class_name="Static")
#    |
#    | Static - 'Source :'    (L958, T618, R1000, B631)
#    | ['Static13', 'Source :', 'Source :Static']
#    | child_window(title="Source :", class_name="Static")
#    |
#    | Static - '720/28224 lines'    (L1003, T618, R1093, B633)
#    | ['Static14', '720/28224 linesStatic', '720/28224 lines']
#    | child_window(title="720/28224 lines", class_name="Static")
#    |
#    | Static - 'Exported :'    (L945, T644, R1001, B659)
#    | ['Static15', 'Exported :', 'Exported :Static']
#    | child_window(title="Exported :", class_name="Static")
#    |
#    | Static - 'LGX file - 51.00 Mb - 24710 lines'    (L1003, T644, R1245, B659)
#    | ['Static16', 'LGX file - 51.00 Mb - 24710 linesStatic', 'LGX file - 51.00 Mb - 24710 lines']
#    | child_window(title="LGX file - 51.00 Mb - 24710 lines", class_name="Static")
#    |
#    | GroupBox - 'Bitmap infos'    (L943, T595, R1257, B671)
#    | ['Bitmap infos', 'GroupBox5', 'Bitmap infosGroupBox', 'Bitmap infosGroupBox0', 'Bitmap infosGroupBox1']
#    | child_window(title="Bitmap infos", class_name="Button")
#    |
#    | GroupBox - ''    (L948, T683, R1031, B772)
#    | ['GroupBox6', 'Bitmap infosGroupBox2']
#    | child_window(class_name="Button")
#    |
#    | RadioButton - 'BMP'    (L954, T693, R992, B709)
#    | ['BMP', 'BMPRadioButton', 'RadioButton', 'RadioButton0', 'RadioButton1']
#    | child_window(title="BMP", class_name="Button")
#    |
#    | RadioButton - 'TIFF'    (L954, T709, R992, B725)
#    | ['RadioButton2', 'TIFFRadioButton', 'TIFF']
#    | child_window(title="TIFF", class_name="Button")
#    |
#    | RadioButton - 'JPG'    (L954, T725, R992, B741)
#    | ['JPG', 'RadioButton3', 'JPGRadioButton']
#    | child_window(title="JPG", class_name="Button")
#    |
#    | CheckBox - 'LGX Format'    (L954, T746, R1028, B772)
#    | ['LGX FormatCheckBox', 'LGX Format', 'CheckBox2']
#    | child_window(title="LGX Format", class_name="Button")
#    |
#    | GroupBox - ''    (L1033, T683, R1114, B745)
#    | ['True colorGroupBox', 'GroupBox7', 'True colorGroupBox0', 'True colorGroupBox1']
#    | child_window(class_name="Button")
#    |
#    | RadioButton - 'True color'    (L1039, T693, R1108, B709)
#    | ['True color', 'RadioButton4', 'True colorRadioButton']
#    | child_window(title="True color", class_name="Button")
#    |
#    | RadioButton - 'B/W'    (L1039, T709, R1108, B725)
#    | ['B/WRadioButton', 'RadioButton5', 'B/W']
#    | child_window(title="B/W", class_name="Button")
#    |
#    | GroupBox - ''    (L1116, T683, R1197, B745)
#    | ['True colorGroupBox2', 'GroupBox8']
#    | child_window(class_name="Button")
#    |
#    | RadioButton - 'Bilinear'    (L1123, T693, R1182, B709)
#    | ['Bilinear', 'RadioButton6', 'BilinearRadioButton']
#    | child_window(title="Bilinear", class_name="Button")
#    |
#    | RadioButton - 'Bicubic'    (L1123, T709, R1182, B725)
#    | ['RadioButton7', 'BicubicRadioButton', 'Bicubic']
#    | child_window(title="Bicubic", class_name="Button")
#    |
#    | Static - 'Decimal'    (L1204, T689, R1245, B704)
#    | ['Static17', 'Decimal', 'DecimalStatic']
#    | child_window(title="Decimal", class_name="Static")
#    |
#    | ComboBox - '2'    (L1204, T710, R1248, B731)
#    | ['DecimalComboBox', 'ComboBox3']
#    | child_window(title="2", class_name="ComboBox")
#    |
#    | CheckBox - 'Draw depth scale'    (L1050, T753, R1163, B766)
#    | ['Draw depth scale', 'Draw depth scaleCheckBox', 'CheckBox3']
#    | child_window(title="Draw depth scale", class_name="Button")
#    |
#    | ComboBox - 'Yellow'    (L1167, T749, R1235, B770)
#    | ['Draw depth scaleComboBox', 'ComboBox4']
#    | child_window(title="Yellow", class_name="ComboBox")
#    |
#    | GroupBox - 'Output format'    (L943, T671, R1257, B777)
#    | ['Output format', 'GroupBox9', 'Output formatGroupBox']
#    | child_window(title="Output format", class_name="Button")
#    |
#    | Button - '...'    (L948, T798, R968, B818)
#    | ['...Button2', '...2', 'Button2']
#    | child_window(title="...", class_name="Button")
#    |
#    | Static - 'C:\2026_RTIO\West Angelas\Sent\GR26WAH0001\OTV'    (L970, T800, R1248, B815)
#    | ['C:\\2026_RTIO\\West Angelas\\Sent\\GR26WAH0001\\OTVStatic', 'Static18', 'C:\\2026_RTIO\\West Angelas\\Sent\\GR26WAH0001\\OTV']
#    | child_window(title="C:\2026_RTIO\West Angelas\Sent\GR26WAH0001\OTV", class_name="Static")
#    |
#    | GroupBox - 'Viewer used after generation'    (L945, T837, R1256, B878)
#    | ['Viewer used after generationGroupBox', 'Viewer used after generation', 'GroupBox10']
#    | child_window(title="Viewer used after generation", class_name="Button")
#    |
#    | CheckBox - 'EMViewer (BMP and JPG)'    (L951, T857, R1091, B870)
#    | ['EMViewer (BMP and JPG)', 'EMViewer (BMP and JPG)CheckBox', 'CheckBox4']
#    | child_window(title="EMViewer (BMP and JPG)", class_name="Button")
#    |
#    | CheckBox - 'HTML generator ( JPG only)'    (L1102, T857, R1254, B870)
#    | ['HTML generator ( JPG only)', 'HTML generator ( JPG only)CheckBox', 'CheckBox5']
#    | child_window(title="HTML generator ( JPG only)", class_name="Button")
#    |
#    | Button - '&Export'    (L1125, T891, R1182, B912)
#    | ['&ExportButton', '&Export', 'Button3']
#    | child_window(title="&Export", class_name="Button")
#    |
#    | Button - '&Cancel'    (L1198, T891, R1255, B912)
#    | ['&Cancel', '&CancelButton', 'Button4']
#    | child_window(title="&Cancel", class_name="Button")
#    |
#    | Static - 'Static'    (L696, T889, R1107, B907)
#    | ['Static19', 'StaticStatic']
#    | child_window(title="Static", class_name="Static")
#    |
#    | Static - 'm'    (L1224, T472, R1238, B485)
#    | ['m2', 'Static20', 'mStatic2']
#    | child_window(title="m", class_name="Static")
#    |
#    | GroupBox - 'Output file(s) Destination'    (L943, T777, R1257, B829)
#    | ['GroupBox11', 'Output file(s) Destination', 'Output file(s) DestinationGroupBox']
#    | child_window(title="Output file(s) Destination", class_name="Button")
#    |
#    | Static - ''    (L687, T398, R926, B879)
#    | ['Static21', 'Picture exportStatic']
#    | child_window(class_name="Static")
#    |
#    | Progress - ''    (L687, T917, R1257, B927)
#    | ['Progress', 'Picture exportProgress']
#    | child_window(class_name="msctls_progress32")

# %%
ctrl = dialog.descendants()[-1]
dir(ctrl)
# Out:
# ['CaptureAsImage',
#  'Children',
#  'Class',
#  'Click',
#  'ClickInput',
#  'ClientRect',
#  'ClientRects',
#  'ClientToScreen',
#  'Close',
#  'CloseAltF4',
#  'CloseClick',
#  'ContextHelpID',
#  'ControlID',
#  'DebugMessage',
#  'DoubleClick',
#  'DoubleClickInput',
#  'DragMouse',
#  'DragMouseInput',
#  'DrawOutline',
#  'ExStyle',
#  'Font',
#  'Fonts',
#  'FriendlyClassName',
#  'GetActive',
#  'GetFocus',
#  'GetPosition',
#  'GetProperties',
#  'GetShowState',
#  'GetState',
#  'GetStep',
#  'GetToolbar',
#  'HasExStyle',
#  'HasStyle',
#  'IsActive',
#  'IsChild',
#  'IsDialog',
#  'IsEnabled',
#  'IsUnicode',
#  'IsVisible',
#  'Maximize',
#  'Menu',
#  'MenuItem',
#  'MenuItems',
#  'MenuSelect',
#  'Minimize',
#  'MoveMouse',
#  'MoveMouseInput',
#  'MoveWindow',
#  'NotifyParent',
#  'Owner',
#  'Parent',
#  'PopupWindow',
#  'PostCommand',
#  'PostMessage',
#  'PressMouse',
#  'PressMouseInput',
#  'ProcessID',
#  'Rectangle',
#  'ReleaseMouse',
#  'ReleaseMouseInput',
#  'Restore',
#  'RightClick',
#  'RightClickInput',
#  'Scroll',
#  'SendCommand',
#  'SendMessage',
#  'SendMessageTimeout',
#  'SetApplicationData',
#  'SetFocus',
#  'SetPosition',
#  'SetTransparency',
#  'SetWindowText',
#  'StepIt',
#  'Style',
#  'Texts',
#  'TopLevelParent',
#  'TypeKeys',
#  'UserData',
#  'VerifyActionable',
#  'VerifyEnabled',
#  'VerifyVisible',
#  'WheelMouseInput',
#  'WindowText',
#  '_BaseWrapper__repr_texts',
#  '_NeedsImageProp',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_as_parameter_',
#  '_cache',
#  '_calc_click_coords',
#  '_create_wrapper',
#  '_element_info',
#  '_ensure_enough_privileges',
#  '_menu_handle',
#  '_needs_image_prop',
#  '_scroll_types',
#  'actions',
#  'appdata',
#  'automation_id',
#  'backend',
#  'can_be_label',
#  'capture_as_image',
#  'children',
#  'class_name',
#  'click',
#  'click_input',
#  'client_rect',
#  'client_rects',
#  'client_to_screen',
#  'close',
#  'close_alt_f4',
#  'close_click',
#  'context_help_id',
#  'control_count',
#  'control_id',
#  'control_type',
#  'debug_message',
#  'descendants',
#  'double_click',
#  'double_click_input',
#  'drag_mouse',
#  'drag_mouse_input',
#  'draw_outline',
#  'element_info',
#  'exstyle',
#  'font',
#  'fonts',
#  'friendly_class_name',
#  'friendlyclassname',
#  'from_point',
#  'full_control_type',
#  'get_active',
#  'get_focus',
#  'get_position',
#  'get_properties',
#  'get_show_state',
#  'get_state',
#  'get_step',
#  'get_toolbar',
#  'handle',
#  'has_exstyle',
#  'has_focus',
#  'has_keyboard_focus',
#  'has_style',
#  'has_title',
#  'is_active',
#  'is_child',
#  'is_dialog',
#  'is_enabled',
#  'is_maximized',
#  'is_minimized',
#  'is_normal',
#  'is_unicode',
#  'is_visible',
#  'iter_children',
#  'iter_descendants',
#  'maximize',
#  'menu',
#  'menu_item',
#  'menu_items',
#  'menu_select',
#  'minimize',
#  'move_mouse',
#  'move_mouse_input',
#  'move_window',
#  'notify_parent',
#  'owner',
#  'parent',
#  'popup_window',
#  'post_command',
#  'post_message',
#  'press_mouse',
#  'press_mouse_input',
#  'process_id',
#  'rectangle',
#  'ref',
#  'release_mouse',
#  'release_mouse_input',
#  'restore',
#  'right_click',
#  'right_click_input',
#  'root',
#  'scroll',
#  'send_chars',
#  'send_command',
#  'send_keystrokes',
#  'send_message',
#  'send_message_timeout',
#  'set_application_data',
#  'set_focus',
#  'set_keyboard_focus',
#  'set_position',
#  'set_transparency',
#  'set_window_text',
#  'step_it',
#  'style',
#  'texts',
#  'top_from_point',
#  'top_level_parent',
#  'type_keys',
#  'user_data',
#  'verify_actionable',
#  'verify_enabled',
#  'verify_visible',
#  'wait_for_idle',
#  'was_maximized',
#  'wheel_mouse_input',
#  'window_text',
#  'windowclasses',
#  'writable_props']

# %%
type(ctrl)
# Out:
# pywinauto.application.WindowSpecification

# %%
buttons = []

for ctrl in dialog.descendants():
    try:
        if ctrl.friendly_class_name() == "Button":
            print(
                "Text:", ctrl.window_text(),
                "| Enabled:", ctrl.is_enabled(),
                "| Rect:", ctrl.rectangle()
            )
            buttons.append(ctrl)
    except Exception as e:
        print("Skipped control:", e)
# Out:
# Text: ... | Enabled: True | Rect: (L1204, T416, R1224, B436)
# Text: ... | Enabled: True | Rect: (L948, T798, R968, B818)
# Text: &Export | Enabled: False | Rect: (L1125, T891, R1182, B912)
# Text: &Cancel | Enabled: True | Rect: (L1198, T891, R1255, B912)

# %%
input_btn = buttons[0].click_input()
import pyperclip

# %%
hed_file = r"C:\2026_RTIO\West Angelas\Sent\GR26WAH0001\OTV\GR26WAH0001_OBI_INRUN.hed"
open_dialog = Desktop(backend="win32").window(
    title="Open",
    class_name="#32770"
)

open_dialog.wait("exists visible ready", timeout=10)
open_dialog.set_focus()

pyperclip.copy(hed_file)

# Focus File name field
open_dialog.type_keys("%n")
time.sleep(0.2)

# Replace current *.hed with actual file path
open_dialog.type_keys("^a")
open_dialog.type_keys("^v")
time.sleep(0.2)

# Press Open
open_dialog.type_keys("{ENTER}")
# Out:
# <hwndwrapper.DialogWrapper - 'Open', Dialog, 13900396>

# %%
dialog = Desktop(backend="win32").window(
    title="Picture export",
    class_name="#32770"
)

dialog.wait("exists visible ready", timeout=10)
dialog.set_focus()

set_true_color = dialog.child_window(title="True color", class_name="Button")
tc_state = set_true_color.get_check_state()
if tc_state == 0:
    set_true_color.click_input(title="True color", class_name="Button")

set_interp = dialog.child_window(title="Bicubic", class_name="Button")
interp_state = set_interp.get_check_state()
if interp_state == 0:
    set_interp.click_input(title="Bicubic", class_name="Button")
    
lgx_checkbox = dialog.child_window(
    title="LGX Format",
    class_name="Button"
)

lgx_checkbox.wait("enabled", timeout=10)

# Check current state: 0 = unchecked, 1 = checked
state = lgx_checkbox.get_check_state()
print("LGX state before:", state)

if state == 0:
    lgx_checkbox.click_input()

time.sleep(0.3)

print("LGX state after:", lgx_checkbox.get_check_state())
# Out:
# LGX state before: 0
# LGX state after: 1

# %%
lgx_export = dialog.child_window(

    title = '&Export',
    class_name = "Button"
)

lgx_export.click_input()
# test the progress bar


#   | Progress - ''    (L2538, T680, R3108, B690)
#   | ['Progress', 'Picture exportProgress']
#   | child_window(class_name="msctls_progress32")
for i in range(100):
    progress = dialog.child_window(class_name="msctls_progress32")
    time.sleep(0.1)

# %%
for w in Desktop(backend="win32").windows():
    try:
        print(
            "Title:", repr(w.window_text()),
            "| Class:", w.class_name(),
            "| Handle:", w.handle
        )
    except Exception as e:
        print("Skipped:", e)
# Out:
# Title: 'DPM' | Class: Qt5152QWindowOwnDCIcon | Handle: 1510456
# Title: '' | Class: ThumbnailDeviceHelperWnd | Handle: 7740210
# Title: '' | Class: ForegroundStaging | Handle: 12131044
# Title: '' | Class: ForegroundStaging | Handle: 1776962
# Title: '' | Class: ThumbnailDeviceHelperWnd | Handle: 3941504
# Title: '' | Class: tooltips_class32 | Handle: 24448886
# Title: '' | Class: tooltips_class32 | Handle: 8659816
# Title: '' | Class: tooltips_class32 | Handle: 25760268
# Title: '' | Class: tooltips_class32 | Handle: 15536974
# Title: '' | Class: tooltips_class32 | Handle: 7543878
# Title: '' | Class: tooltips_class32 | Handle: 2761848
# Title: '' | Class: tooltips_class32 | Handle: 8983232
# Title: '' | Class: Shell_TrayWnd | Handle: 530010
# Title: '' | Class: Shell_SecondaryTrayWnd | Handle: 2892966
# Title: '' | Class: tooltips_class32 | Handle: 17503970
# Title: '' | Class: tooltips_class32 | Handle: 7865182
# Title: 'Microsoft Teams | Pinned window' | Class: TeamsWebView | Handle: 16589668
# Title: '' | Class: Auto-Suggest Dropdown | Handle: 1576986
# Title: 'HardwareMonitorWindow' | Class: HardwareMonitorWindowClass | Handle: 13967310
# Title: '' | Class: NotifyIconOverflowWindow | Handle: 8392550
# Title: 'Battery Meter' | Class: SystemTray_Main | Handle: 27527008
# Title: '' | Class: ATL:00007FFF7FAD0550 | Handle: 4661442
# Title: 'Network Flyout' | Class: ATL:00007FFF2F89D230 | Handle: 330596
# Title: '' | Class: PNIHiddenWnd | Handle: 5442342
# Title: '' | Class: tooltips_class32 | Handle: 47711308
# Title: '' | Class: tooltips_class32 | Handle: 5382924
# Title: '' | Class: tooltips_class32 | Handle: 6754842
# Title: '' | Class: tooltips_class32 | Handle: 7414868
# Title: '' | Class: tooltips_class32 | Handle: 4526652
# Title: '' | Class: tooltips_class32 | Handle: 9898454
# Title: '' | Class: tooltips_class32 | Handle: 15993602
# Title: '' | Class: tooltips_class32 | Handle: 13046084
# Title: '' | Class: tooltips_class32 | Handle: 41028206
# Title: '' | Class: tooltips_class32 | Handle: 26942308
# Title: 'Invalid Depth !!!' | Class: #32770 | Handle: 18684454
# Title: '' | Class: tooltips_class32 | Handle: 8719066
# Title: '' | Class: tooltips_class32 | Handle: 7150932
# Title: '' | Class: tooltips_class32 | Handle: 19341072
# Title: '' | Class: tooltips_class32 | Handle: 5113698
# Title: '' | Class: tooltips_class32 | Handle: 7019926
# Title: '' | Class: tooltips_class32 | Handle: 12131632
# Title: '' | Class: tooltips_class32 | Handle: 11475976
# Title: '' | Class: tooltips_class32 | Handle: 29497116
# Title: '' | Class: tooltips_class32 | Handle: 24712568
# Title: '' | Class: tooltips_class32 | Handle: 10231908
# Title: '' | Class: tooltips_class32 | Handle: 13635440
# Title: '' | Class: tooltips_class32 | Handle: 19928198
# Title: '' | Class: tooltips_class32 | Handle: 39979466
# Title: '' | Class: tooltips_class32 | Handle: 10756374
# Title: '' | Class: tooltips_class32 | Handle: 17303704
# Title: '● trial.ipynb - Project_Fatemah - Visual Studio Code' | Class: Chrome_WidgetWin_1 | Handle: 15147014
# Title: 'Picture export' | Class: #32770 | Handle: 8788594
# Title: '' | Class: #32770 | Handle: 15735380
# Title: 'Diagnostic panel' | Class: #32770 | Handle: 5971362
# Title: 'Technical tools' | Class: #32770 | Handle: 4202604
# Title: 'Camera control' | Class: #32770 | Handle: 31264656
# Title: 'Logger Setup' | Class: #32770 | Handle: 13377190
# Title: 'Deviation Data' | Class: #32770 | Handle: 8000244
# Title: 'Depth magnifier' | Class: #32770 | Handle: 12651394
# Title: 'OPTV Acquisition software version\xa02.00' | Class: #32770 | Handle: 13173516
# Title: '' | Class: ComboLBox | Handle: 9705372
# Title: '' | Class: ComboLBox | Handle: 1311780
# Title: '' | Class: ComboLBox | Handle: 35527466
# Title: '' | Class: ComboLBox | Handle: 25301272
# Title: '' | Class: ComboLBox | Handle: 19535752
# Title: '' | Class: ComboLBox | Handle: 9115772
# Title: '' | Class: ComboLBox | Handle: 9771328
# Title: '' | Class: ComboLBox | Handle: 19076944
# Title: '' | Class: ComboLBox | Handle: 7080654
# Title: '' | Class: ComboLBox | Handle: 11211798
# Title: '' | Class: ComboLBox | Handle: 8262656
# Title: '' | Class: ComboLBox | Handle: 10556294
# Title: '' | Class: ComboLBox | Handle: 21300042
# Title: 'eMindLogger' | Class: #32770 | Handle: 2689488
# Title: 'Claude' | Class: Chrome_WidgetWin_1 | Handle: 9837862
# Title: 'DesktopWindowXamlSource' | Class: Windows.UI.Core.CoreWindow | Handle: 15208566
# Title: 'EmbeddedMenuWindow' | Class: EmbeddedMenuWindowClass | Handle: 8914540
# Title: 'MenuWindow' | Class: MenuWindowClass | Handle: 11931794
# Title: 'TclNotifier' | Class: TclNotifier | Handle: 11079828
# Title: 'TtkMonitorWindow' | Class: TtkMonitorClass | Handle: 6226170
# Title: 'PopupHost' | Class: Microsoft.UI.Content.PopupWindowSiteBridge | Handle: 19404952
# Title: '' | Class: tooltips_class32 | Handle: 7603766
# Title: '' | Class: tooltips_class32 | Handle: 33758118
# Title: 'test and 1 more tab - File Explorer' | Class: CabinetWClass | Handle: 6558746
# Title: '100% complete' | Class: OperationStatusWindow | Handle: 12915252
# Title: 'Australia Wireline Group - Documents - 6 June - All Documents and 4 more pages - Work - Microsoft\u200b Edge' | Class: Chrome_WidgetWin_1 | Handle: 2299406
# Title: '' | Class: MessageWindowClass | Handle: 4199544
# Title: '' | Class: ComboLBox | Handle: 10027244
# Title: '' | Class: tooltips_class32 | Handle: 42537768
# Title: '' | Class: TWizardForm | Handle: 28971054
# Title: '' | Class: TApplication | Handle: 13637114
# Title: '' | Class: TPUtilWindow | Handle: 13574114
# Title: 'InnoSetupLdrWindow' | Class: Static | Handle: 10750646
# Title: '' | Class: Hidden Window of the IM Abstraction layer | Handle: 26086832
# Title: 'W' | Class: WMS Notif Engine:Dispatch Window Class | Handle: 8328764
# Title: '' | Class: MsoPeopleSearchMessages | Handle: 13574444
# Title: '' | Class: MsoStdCompMgr | Handle: 14556552
# Title: '2026 Repeatability Holes - Logging Intervals.docx  -  Last saved by user - Word' | Class: OpusApp | Handle: 9964198
# Title: '' | Class: ThunderMain | Handle: 15209822
# Title: 'AcroStubUnloadWClass' | Class: AcroStubUnloadWClass | Handle: 13965556
# Title: 'DDE Server Window' | Class: OleDdeWndClass | Handle: 7930050
# Title: '' | Class: _WwO | Handle: 19275672
# Title: 'OfficePowerManagerWindow' | Class: OfficePowerManagerWindow | Handle: 13767916
# Title: '' | Class: ARC Event Window 00 | Handle: 35004384
# Title: '' | Class: ARC Event Window 00 | Handle: 14091658
# Title: '' | Class: ARC Event Window 00 | Handle: 32247138
# Title: '' | Class: PseudoConsoleWindow | Handle: 14951172
# Title: 'DesktopWindowXamlSource' | Class: Windows.UI.Core.CoreWindow | Handle: 11600098
# Title: '' | Class: PseudoConsoleWindow | Handle: 17761582
# Title: '' | Class: PseudoConsoleWindow | Handle: 10359100
# Title: '' | Class: PseudoConsoleWindow | Handle: 9772818
# Title: '' | Class: PseudoConsoleWindow | Handle: 2491332
# Title: '' | Class: PseudoConsoleWindow | Handle: 8461750
# Title: 'PopupHost' | Class: Microsoft.UI.Content.PopupWindowSiteBridge | Handle: 23792002
# Title: '' | Class: tooltips_class32 | Handle: 12916962
# Title: '' | Class: tooltips_class32 | Handle: 6751438
# Title: '' | Class: tooltips_class32 | Handle: 7343066
# Title: '26BKRC011 and 2 more tabs - File Explorer' | Class: CabinetWClass | Handle: 7995830
# Title: '' | Class: Shell Preview Extension Temporary Parent | Handle: 32509370
# Title: 'depth_utils.py - Cloud-App - Visual Studio Code' | Class: Chrome_WidgetWin_1 | Handle: 66936
# Title: '' | Class: ApplicationManager_DesktopShellWindow | Handle: 13900936
# Title: '' | Class: WorkerW | Handle: 4655912
# Title: '' | Class: PseudoConsoleWindow | Handle: 9704244
# Title: '' | Class: PseudoConsoleWindow | Handle: 16849330
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 8261212
# Title: '' | Class: pwahelper_wnd | Handle: 12191280
# Title: '' | Class: Chrome_StatusTrayWindow | Handle: 24779600
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 47914852
# Title: '' | Class: Base_PowerMessageWindow | Handle: 16390396
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 10953338
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 15472690
# Title: '' | Class: pwahelper_wnd | Handle: 13441034
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 6428362
# Title: '' | Class: WorkerW | Handle: 10750262
# Title: '' | Class: WorkerW | Handle: 15409524
# Title: '' | Class: PseudoConsoleWindow | Handle: 51059740
# Title: '' | Class: PseudoConsoleWindow | Handle: 9052010
# Title: '' | Class: PseudoConsoleWindow | Handle: 18682422
# Title: '' | Class: PseudoConsoleWindow | Handle: 17374144
# Title: '' | Class: PseudoConsoleWindow | Handle: 29886760
# Title: '' | Class: PseudoConsoleWindow | Handle: 55117024
# Title: '' | Class: PseudoConsoleWindow | Handle: 3744904
# Title: '' | Class: PseudoConsoleWindow | Handle: 17829260
# Title: '' | Class: PseudoConsoleWindow | Handle: 6694012
# Title: '' | Class: PseudoConsoleWindow | Handle: 58134738
# Title: '' | Class: PseudoConsoleWindow | Handle: 25433950
# Title: '' | Class: PseudoConsoleWindow | Handle: 15866004
# Title: '' | Class: PseudoConsoleWindow | Handle: 6885616
# Title: '' | Class: PseudoConsoleWindow | Handle: 8134106
# Title: 'Streamlit - Calibration · Streamlit' | Class: Chrome_WidgetWin_1 | Handle: 10755418
# Title: 'Inbox - Zexin Yu - Outlook' | Class: Outlook Host | Handle: 526860
# Title: 'Chat | Workflows | WIRELINE SERVICES GROUP PTY LTD | zexinyu@wirelineservices.com.au | Microsoft Teams' | Class: TeamsWebView | Handle: 24380072
# Title: 'ChatGPT - work general - Python Windows Automation' | Class: Chrome_WidgetWin_1 | Handle: 1705040
# Title: '' | Class: tooltips_class32 | Handle: 40440520
# Title: '' | Class: tooltips_class32 | Handle: 30477700
# Title: '' | Class: tooltips_class32 | Handle: 11209946
# Title: 'C:\\Century\\data\\DD22TPM0002_MASTER.las - Notepad++' | Class: Notepad++ | Handle: 24972810
# Title: 'TV Pipeline Launcher' | Class: TkTopLevel | Handle: 9634754
# Title: '' | Class: WindowsDashboard | Handle: 199700
# Title: '' | Class: PrintCacheLocalConnectionListenerHiddenWindow | Handle: 21830772
# Title: '' | Class: PrintCacheListenerWindow_19A79E3F-0006-4175-AACD-6F5C69CC0D23 | Handle: 16065012
# Title: '' | Class: ASYNCUI_NOTIFYICON_WINDOW_CLASS | Handle: 10165338
# Title: '' | Class: PrintTray_Notify_WndClass | Handle: 38478420
# Title: '' | Class: WorkerW | Handle: 14885318
# Title: '' | Class: WorkerW | Handle: 27263436
# Title: '' | Class: WorkerW | Handle: 7799274
# Title: '' | Class: WorkerW | Handle: 9708546
# Title: '' | Class: WorkerW | Handle: 3415566
# Title: 'GDI+ Window (Explorer.EXE)' | Class: GDI+ Hook Window Class | Handle: 2168134
# Title: '' | Class: ApplicationFrameWindow | Handle: 989974
# Title: '' | Class: WorkerW | Handle: 4067154
# Title: '' | Class: tooltips_class32 | Handle: 19601412
# Title: '' | Class: tooltips_class32 | Handle: 8003998
# Title: '' | Class: WorkerW | Handle: 36900086
# Title: '' | Class: PseudoConsoleWindow | Handle: 17500738
# Title: '' | Class: WorkerW | Handle: 729436
# Title: '' | Class: WorkerW | Handle: 4329852
# Title: '' | Class: WorkerW | Handle: 1252620
# Title: 'Detailed Log' | Class: #32770 | Handle: 17039858
# Title: 'PDF-XChange Updater - 11.0.1.0' | Class: TrackerUpdateWndClass | Handle: 3283254
# Title: '' | Class: tooltips_class32 | Handle: 2892118
# Title: 'MS_WebcheckMonitor' | Class: MS_WebcheckMonitor | Handle: 19469982
# Title: 'BluetoothNotificationAreaIconWindowClass' | Class: BluetoothNotificationAreaIconWindowClass | Handle: 6098902
# Title: '' | Class: WorkerW | Handle: 21238916
# Title: '' | Class: WorkerW | Handle: 20777814
# Title: '' | Class: WorkerW | Handle: 9509182
# Title: '' | Class: WorkerW | Handle: 5708194
# Title: '' | Class: DummyDWMListenerWindow | Handle: 11014462
# Title: '' | Class: TabletModeCoverWindow | Handle: 1052970
# Title: '' | Class: TabletModeCoverWindow | Handle: 1773874
# Title: '' | Class: EdgeUiInputTopWndClass | Handle: 4136054
# Title: '' | Class: EdgeUiInputTopWndClass | Handle: 31985098
# Title: '' | Class: Postures Broadcast Listener Class | Handle: 14686296
# Title: '' | Class: DummyDWMListenerWindow | Handle: 656554
# Title: '' | Class: DummyDWMListenerWindow | Handle: 791616
# Title: '' | Class: DummyDWMListenerWindow | Handle: 10162266
# Title: '' | Class: DummyDWMListenerWindow | Handle: 16784864
# Title: '' | Class: WorkerW | Handle: 12651538
# Title: '' | Class: WorkerW | Handle: 394564
# Title: '' | Class: WorkerW | Handle: 8127930
# Title: '' | Class: WorkerW | Handle: 6161004
# Title: '' | Class: WorkerW | Handle: 6030026
# Title: '' | Class: DDEMLEvent | Handle: 11866776
# Title: '' | Class: DDEMLMom | Handle: 28119908
# Title: '' | Class: PseudoConsoleWindow | Handle: 14358232
# Title: '' | Class: PseudoConsoleWindow | Handle: 5840818
# Title: '' | Class: PseudoConsoleWindow | Handle: 18877076
# Title: '' | Class: PseudoConsoleWindow | Handle: 20125650
# Title: '' | Class: PseudoConsoleWindow | Handle: 7668452
# Title: '' | Class: PseudoConsoleWindow | Handle: 20972600
# Title: '' | Class: PseudoConsoleWindow | Handle: 11409954
# Title: '' | Class: PseudoConsoleWindow | Handle: 926594
# Title: 'DDE Server Window' | Class: OleDdeWndClass | Handle: 46137540
# Title: '' | Class: PseudoConsoleWindow | Handle: 14881652
# Title: '' | Class: PseudoConsoleWindow | Handle: 17175586
# Title: '' | Class: PseudoConsoleWindow | Handle: 2237376
# Title: '' | Class: PseudoConsoleWindow | Handle: 18749190
# Title: '' | Class: PseudoConsoleWindow | Handle: 10097882
# Title: '' | Class: PseudoConsoleWindow | Handle: 20251254
# Title: '' | Class: PseudoConsoleWindow | Handle: 9568680
# Title: '' | Class: PseudoConsoleWindow | Handle: 1902152
# Title: 'Windows Input Experience' | Class: Windows.UI.Core.CoreWindow | Handle: 24255954
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 1314196
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 6888248
# Title: '' | Class: Electron_NotifyIconHostWindow | Handle: 6758298
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 9901718
# Title: '' | Class: Chrome_WidgetWin_1 | Handle: 18880912
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 8262418
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 18814722
# Title: '' | Class: Base_PowerMessageWindow | Handle: 6555412
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 15139900
# Title: '' | Class: InputSiteWindowClass | Handle: 4858968
# Title: 'M365 Copilot quick view' | Class: Microsoft 365 Copilot Host | Handle: 24122366
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 593310
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 5577312
# Title: '' | Class: Base_PowerMessageWindow | Handle: 854202
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 22285822
# Title: 'Microsoft 365 Copilot' | Class: Microsoft 365 Copilot Host | Handle: 8921512
# Title: 'GDI+ Window (M365Copilot.exe)' | Class: GDI+ Hook Window Class | Handle: 26873696
# Title: '' | Class: Microsoft 365 Copilot Staging Area | Handle: 1248514
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 1312436
# Title: 'Rtc Video PnP Listener' | Class: RtcPalVideoPnPMonitorHWND | Handle: 19272022
# Title: '' | Class: SkyLibWindowsReactor | Handle: 21501336
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 36181928
# Title: '' | Class: TeamsMessageWindow | Handle: 11871296
# Title: 'Microsoft Teams' | Class: TeamsWebView | Handle: 9838622
# Title: '' | Class: ContextSwitcherImpl | Handle: 16190866
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 1772570
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 4328160
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 3081944
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 1117602
# Title: '' | Class: Base_PowerMessageWindow | Handle: 1902656
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 6232506
# Title: 'DDE Server Window' | Class: OleDdeWndClass | Handle: 7804536
# Title: '' | Class: TeamsMessageWindow | Handle: 8259194
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 329904
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 329832
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 10158756
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 460672
# Title: '' | Class: Base_PowerMessageWindow | Handle: 5637550
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 7216228
# Title: ' - WIRELINE SERVICES GROUP PTY LTDEmpty WebView2' | Class: WebView2 | Handle: 8262002
# Title: 'Microsoft OneDrive Sync Service' | Class: Nucleus Auth Window | Handle: 9898708
# Title: '' | Class: ATL:00007FFF3EFBC0C0 | Handle: 722628
# Title: '' | Class: ContextSwitcherImpl | Handle: 329788
# Title: '' | Class: ATL:00007FFF3EFBC0C0 | Handle: 329620
# Title: '' | Class: ATL:00007FFF3EFBC0C0 | Handle: 393584
# Title: '' | Class: ATL:00007FFF3EFBC0C0 | Handle: 21761722
# Title: 'OneDrive - WIRELINE SERVICES GROUP PTY LTD' | Class: SkyDrive Class Name {090B42FF-7B26-4416-99B6-CB17896CF07C}-Business1 | Handle: 264060
# Title: '' | Class: ATL:00007FFF3EFBC0C0 | Handle: 329608
# Title: '' | Class: SubscriptionDispatcher | Handle: 16846446
# Title: '' | Class: ExtensionHostLogger | Handle: 395798
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 1248220
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 14090970
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 30544726
# Title: '' | Class: Base_PowerMessageWindow | Handle: 330410
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 22217188
# Title: '' | Class: TrayInstanceWindow | Handle: 5309956
# Title: '' | Class: SystemHealthMonitor | Handle: 722434
# Title: '' | Class: OlkMessageHandler | Handle: 17500234
# Title: '' | Class: Outlook Staging Area | Handle: 461276
# Title: '' | Class: ContextSwitcherImpl | Handle: 43976938
# Title: '' | Class: PseudoConsoleWindow | Handle: 43717504
# Title: '' | Class: PseudoConsoleWindow | Handle: 5377790
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 8851688
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 11212242
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 16130726
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 264812
# Title: '' | Class: Base_PowerMessageWindow | Handle: 723952
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 134182
# Title: '' | Class: MessageWindowClass | Handle: 134160
# Title: '.NET-BroadcastEventWindow.bf7771.0' | Class: .NET-BroadcastEventWindow.bf7771.0 | Handle: 29957222
# Title: '' | Class: WorkerW | Handle: 12327566
# Title: '' | Class: WorkerW | Handle: 25693926
# Title: '' | Class: WorkerW | Handle: 5052658
# Title: 'DesktopWindowXamlSource' | Class: Windows.UI.Core.CoreWindow | Handle: 12848358
# Title: '' | Class: WorkerW | Handle: 13111100
# Title: 'DesktopWindowXamlSource' | Class: Windows.UI.Core.CoreWindow | Handle: 4071144
# Title: '' | Class: PersonalizationThemeChangeListener | Handle: 199246
# Title: '' | Class: WorkerW | Handle: 264702
# Title: '' | Class: Windows.UI.Core.CoreWindow | Handle: 1247894
# Title: 'Settings' | Class: ApplicationFrameWindow | Handle: 199300
# Title: 'QTrayIconMessageWindow' | Class: Qt51514TrayIconMessageWindowClass | Handle: 196764
# Title: '' | Class: WorkerW | Handle: 8854894
# Title: '' | Class: WorkerW | Handle: 8458308
# Title: 'DesktopWindowXamlSource' | Class: Windows.UI.Core.CoreWindow | Handle: 332888
# Title: 'Task Host Window' | Class: COMTASKSWINDOWCLASS | Handle: 12519540
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 396458
# Title: '' | Class: PseudoConsoleWindow | Handle: 524894
# Title: 'CodeMeterCC' | Class: QWidget | Handle: 131506
# Title: 'CodeMeterCC' | Class: QWidget | Handle: 461116
# Title: 'CodeMeterCC' | Class: QWidget | Handle: 133466
# Title: '' | Class: QEventDispatcherWin32_Internal_Widget9916048 | Handle: 786456
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 131384
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 133356
# Title: '' | Class: Base_PowerMessageWindow | Handle: 67808
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 67804
# Title: 'Realtek Jack Windows - 28' | Class: WavesGenericWindow | Handle: 67622
# Title: 'Realtek Jack Windows - 27' | Class: WavesGenericWindow | Handle: 67618
# Title: 'Realtek Jack Windows - 26' | Class: WavesGenericWindow | Handle: 67614
# Title: 'Realtek Jack Windows - 25' | Class: WavesGenericWindow | Handle: 67610
# Title: 'Realtek Jack Windows - 24' | Class: WavesGenericWindow | Handle: 67606
# Title: 'Realtek Jack Windows - 23' | Class: WavesGenericWindow | Handle: 67602
# Title: 'Realtek Jack Windows - 22' | Class: WavesGenericWindow | Handle: 67598
# Title: 'Realtek Jack Windows - 21' | Class: WavesGenericWindow | Handle: 67594
# Title: 'Realtek Jack Windows - 20' | Class: WavesGenericWindow | Handle: 67590
# Title: 'Realtek Jack Windows - 19' | Class: WavesGenericWindow | Handle: 67586
# Title: 'Realtek Jack Windows - 18' | Class: WavesGenericWindow | Handle: 67582
# Title: 'Realtek Jack Windows - 17' | Class: WavesGenericWindow | Handle: 67576
# Title: 'Realtek Jack Windows - 16' | Class: WavesGenericWindow | Handle: 67570
# Title: 'Realtek Jack Windows - 15' | Class: WavesGenericWindow | Handle: 67566
# Title: 'Realtek Jack Windows - 14' | Class: WavesGenericWindow | Handle: 67562
# Title: 'Realtek Jack Windows - 13' | Class: WavesGenericWindow | Handle: 67558
# Title: 'Realtek Jack Windows - 12' | Class: WavesGenericWindow | Handle: 67554
# Title: 'Realtek Jack Windows - 11' | Class: WavesGenericWindow | Handle: 67550
# Title: 'Realtek Jack Windows - 10' | Class: WavesGenericWindow | Handle: 67546
# Title: 'Realtek Jack Windows - 9' | Class: WavesGenericWindow | Handle: 67542
# Title: 'Realtek Jack Windows - 8' | Class: WavesGenericWindow | Handle: 67538
# Title: 'Realtek Jack Windows - 7' | Class: WavesGenericWindow | Handle: 67534
# Title: 'Realtek Jack Windows - 5' | Class: WavesGenericWindow | Handle: 67530
# Title: 'Realtek Jack Windows - 4' | Class: WavesGenericWindow | Handle: 67526
# Title: 'Realtek Jack Windows - 3' | Class: WavesGenericWindow | Handle: 67522
# Title: 'Realtek Jack Windows - 2' | Class: WavesGenericWindow | Handle: 67518
# Title: 'Realtek Jack Windows - 1' | Class: WavesGenericWindow | Handle: 67514
# Title: 'WavesFXConnection_Capture' | Class: WavesGenericWindow | Handle: 67512
# Title: 'ChangeNotify' | Class: WavesNotifications00000235B0DD5210 | Handle: 67510
# Title: 'WavesFXConnection_Render' | Class: WavesGenericWindow | Handle: 198576
# Title: 'ChangeNotify' | Class: WavesNotifications00000235ACE38180 | Handle: 67508
# Title: 'ChangeNotify' | Class: WavesNotifications00000235ACE378F0 | Handle: 133042
# Title: 'AutoSubtypeOnAudioSession' | Class: WavesGenericWindow | Handle: 1181518
# Title: 'Realtek Jack Windows - 6' | Class: WavesGenericWindow | Handle: 395060
# Title: 'Realtek Jack Windows - 0' | Class: WavesGenericWindow | Handle: 67372
# Title: 'RealtekAudioBackgroundProcessClass' | Class: RealtekAudioBackgroundProcessClass | Handle: 262260
# Title: '' | Class: ATL:00007FFF0B43E000 | Handle: 262258
# Title: 'SecurityHealthSystray' | Class: SecHealth Window Class | Handle: 393344
# Title: '' | Class: PseudoConsoleWindow | Handle: 132534
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 131686
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 66914
# Title: '' | Class: Electron_SystemPreferencesHostWindow | Handle: 66912
# Title: '' | Class: Chrome_WidgetWin_0 | Handle: 66910
# Title: '' | Class: Base_PowerMessageWindow | Handle: 66900
# Title: '' | Class: HelperWndClass | Handle: 327816
# Title: 'NvSvc' | Class: NVSVC64.DLL | Handle: 262284
# Title: 'UxdService' | Class: UxdService | Handle: 131442
# Title: 'RealtekAudioAdminBackgroundProcessClass' | Class: RealtekAudioAdminBackgroundProcessClass | Handle: 66666
# Title: 'Windows Push Notifications Platform' | Class: PushNotificationsPowerManagement | Handle: 65840
# Title: '' | Class: ZoomLauncher3rdSdk_HostWindow | Handle: 65830
# Title: 'Task Host Window' | Class: COMTASKSWINDOWCLASS | Handle: 131122
# Title: 'DPM' | Class: Qt5152QWindowIcon | Handle: 131130
# Title: 'NVIDIA WMI Provider' | Class: NVIDIA WMI Provider | Handle: 196790
# Title: '' | Class: crashpad_SessionEndWatcher | Handle: 131232
# Title: 'NvContainerWindowClass0000125C' | Class: NvContainerWindowClass0000125C | Handle: 65630
# Title: 'DWM Notification Window' | Class: Dwm | Handle: 65616
# Title: '' | Class: CicLoaderWndClass | Handle: 1114222
# Title: 'CodeMeter Control Center' | Class: QWidget | Handle: 131546
# Title: 'Location Notification' | Class: LOCATIONNOTIFICATION | Handle: 1051808
# Title: 'Widgets' | Class: Chrome_WidgetWin_1 | Handle: 262248
# Title: '' | Class: WorkerW | Handle: 1640694
# Title: '' | Class: ServiceWorkerGlobalScopeHost Window Class | Handle: 4396750
# Title: 'DDE Server Window' | Class: OleDdeWndClass | Handle: 2626828
# Title: '' | Class: WorkerW | Handle: 19926132
# Title: '' | Class: WorkerW | Handle: 6227030
# Title: 'Program Manager' | Class: Progman | Handle: 36834012
# Title: 'M' | Class: MSCTFIME UI | Handle: 527742
# Title: 'Default IME' | Class: IME | Handle: 131128
# Title: 'Default IME' | Class: IME | Handle: 9834654
# Title: 'M' | Class: MSCTFIME UI | Handle: 10160546
# Title: 'M' | Class: MSCTFIME UI | Handle: 15473990
# Title: 'Default IME' | Class: IME | Handle: 790044
# Title: 'M' | Class: MSCTFIME UI | Handle: 13442044
# Title: 'Default IME' | Class: IME | Handle: 17504242
# Title: 'Default IME' | Class: IME | Handle: 16917204
# Title: 'M' | Class: MSCTFIME UI | Handle: 1049978
# Title: 'Default IME' | Class: IME | Handle: 66902
# Title: 'M' | Class: MSCTFIME UI | Handle: 17302012
# Title: 'Default IME' | Class: IME | Handle: 5115366
# Title: 'M' | Class: MSCTFIME UI | Handle: 43261430
# Title: 'Default IME' | Class: IME | Handle: 10289560
# Title: 'M' | Class: MSCTFIME UI | Handle: 16061254
# Title: 'Default IME' | Class: IME | Handle: 24515404
# Title: 'M' | Class: MSCTFIME UI | Handle: 9248268
# Title: 'Default IME' | Class: IME | Handle: 8392252
# Title: 'Default IME' | Class: IME | Handle: 8520848
# Title: 'Default IME' | Class: IME | Handle: 27203486
# Title: 'Default IME' | Class: IME | Handle: 7937214
# Title: 'M' | Class: MSCTFIME UI | Handle: 1903516
# Title: 'Default IME' | Class: IME | Handle: 2032934
# Title: 'Default IME' | Class: IME | Handle: 5248480
# Title: 'Default IME' | Class: IME | Handle: 54265494
# Title: 'Default IME' | Class: IME | Handle: 17506434
# Title: 'Default IME' | Class: IME | Handle: 4391870
# Title: 'Default IME' | Class: IME | Handle: 3935666
# Title: 'Default IME' | Class: IME | Handle: 22946878
# Title: 'M' | Class: MSCTFIME UI | Handle: 20578856
# Title: 'Default IME' | Class: IME | Handle: 4400042
# Title: 'Default IME' | Class: IME | Handle: 24250264
# Title: 'Default IME' | Class: IME | Handle: 36576004
# Title: 'Default IME' | Class: IME | Handle: 33358744
# Title: 'Default IME' | Class: IME | Handle: 15602986
# Title: 'Default IME' | Class: IME | Handle: 8262062
# Title: 'Default IME' | Class: IME | Handle: 8656356
# Title: 'Default IME' | Class: IME | Handle: 4591640
# Title: 'Default IME' | Class: IME | Handle: 67866
# Title: 'M' | Class: MSCTFIME UI | Handle: 9702186
# Title: 'Default IME' | Class: IME | Handle: 33817840
# Title: 'M' | Class: MSCTFIME UI | Handle: 30214316
# Title: 'Default IME' | Class: IME | Handle: 28844358
# Title: 'M' | Class: MSCTFIME UI | Handle: 8261580
# Title: 'Default IME' | Class: IME | Handle: 7478906
# Title: 'Default IME' | Class: IME | Handle: 30678006
# Title: 'Default IME' | Class: IME | Handle: 7871494
# Title: 'Default IME' | Class: IME | Handle: 19145034
# Title: 'Default IME' | Class: IME | Handle: 1909894
# Title: 'Default IME' | Class: IME | Handle: 13311356
# Title: 'Default IME' | Class: IME | Handle: 14489018
# Title: 'Default IME' | Class: IME | Handle: 5383450
# Title: 'Default IME' | Class: IME | Handle: 13508034
# Title: 'Default IME' | Class: IME | Handle: 21762084
# Title: 'Default IME' | Class: IME | Handle: 8719454
# Title: 'Default IME' | Class: IME | Handle: 11344346
# Title: 'Default IME' | Class: IME | Handle: 23337236
# Title: 'Default IME' | Class: IME | Handle: 46342606
# Title: 'Default IME' | Class: IME | Handle: 20126906
# Title: 'M' | Class: MSCTFIME UI | Handle: 3606162
# Title: 'Default IME' | Class: IME | Handle: 854934
# Title: 'M' | Class: MSCTFIME UI | Handle: 18682780
# Title: 'Default IME' | Class: IME | Handle: 26546316
# Title: 'M' | Class: MSCTFIME UI | Handle: 1582046
# Title: 'Default IME' | Class: IME | Handle: 6101726
# Title: 'M' | Class: MSCTFIME UI | Handle: 5186534
# Title: 'Default IME' | Class: IME | Handle: 5186682
# Title: 'M' | Class: MSCTFIME UI | Handle: 1116434
# Title: 'Default IME' | Class: IME | Handle: 67814
# Title: 'M' | Class: MSCTFIME UI | Handle: 8915692
# Title: 'Default IME' | Class: IME | Handle: 5046634
# Title: 'M' | Class: MSCTFIME UI | Handle: 15666114
# Title: 'Default IME' | Class: IME | Handle: 20123220
# Title: 'M' | Class: MSCTFIME UI | Handle: 12394720
# Title: 'Default IME' | Class: IME | Handle: 22616782
# Title: 'M' | Class: MSCTFIME UI | Handle: 25956018
# Title: 'Default IME' | Class: IME | Handle: 134176
# Title: 'M' | Class: MSCTFIME UI | Handle: 8590556
# Title: 'Default IME' | Class: IME | Handle: 21567710
# Title: 'M' | Class: MSCTFIME UI | Handle: 17242932
# Title: 'Default IME' | Class: IME | Handle: 1048816
# Title: 'M' | Class: MSCTFIME UI | Handle: 24055210
# Title: 'Default IME' | Class: IME | Handle: 1121798
# Title: 'Default IME' | Class: IME | Handle: 3474624
# Title: 'Default IME' | Class: IME | Handle: 7411494
# Title: 'Default IME' | Class: IME | Handle: 5644226
# Title: 'Default IME' | Class: IME | Handle: 22813526
# Title: 'Default IME' | Class: IME | Handle: 13043078
# Title: 'Default IME' | Class: IME | Handle: 394914
# Title: 'Default IME' | Class: IME | Handle: 14424168
# Title: 'M' | Class: MSCTFIME UI | Handle: 2367536
# Title: 'Default IME' | Class: IME | Handle: 2499666
# Title: 'Default IME' | Class: IME | Handle: 11472070
# Title: 'Default IME' | Class: IME | Handle: 15997054
# Title: 'Default IME' | Class: IME | Handle: 4661416
# Title: 'Default IME' | Class: IME | Handle: 10947060
# Title: 'Default IME' | Class: IME | Handle: 5906634
# Title: 'Default IME' | Class: IME | Handle: 20977468
# Title: 'Default IME' | Class: IME | Handle: 22156358
# Title: 'Default IME' | Class: IME | Handle: 8457912
# Title: 'Default IME' | Class: IME | Handle: 27074792
# Title: 'Default IME' | Class: IME | Handle: 9177262
# Title: 'Default IME' | Class: IME | Handle: 13047388
# Title: 'Default IME' | Class: IME | Handle: 39717312
# Title: 'Default IME' | Class: IME | Handle: 19799772
# Title: 'Default IME' | Class: IME | Handle: 10947298
# Title: 'Default IME' | Class: IME | Handle: 15866766
# Title: 'Default IME' | Class: IME | Handle: 1057684
# Title: 'Default IME' | Class: IME | Handle: 8397428
# Title: 'Default IME' | Class: IME | Handle: 3810018
# Title: 'Default IME' | Class: IME | Handle: 1319788
# Title: 'Default IME' | Class: IME | Handle: 16261118
# Title: 'Default IME' | Class: IME | Handle: 3676742
# Title: 'Default IME' | Class: IME | Handle: 30349898
# Title: 'Default IME' | Class: IME | Handle: 29106334
# Title: 'Default IME' | Class: IME | Handle: 1117276
# Title: 'Default IME' | Class: IME | Handle: 721184
# Title: 'Default IME' | Class: IME | Handle: 15671288
# Title: 'Default IME' | Class: IME | Handle: 5376050
# Title: 'Default IME' | Class: IME | Handle: 18158282
# Title: 'Default IME' | Class: IME | Handle: 60821054
# Title: 'Default IME' | Class: IME | Handle: 16712270
# Title: 'Default IME' | Class: IME | Handle: 5835578
# Title: 'Default IME' | Class: IME | Handle: 9045564
# Title: 'Default IME' | Class: IME | Handle: 11211582
# Title: 'Default IME' | Class: IME | Handle: 264076
# Title: 'Default IME' | Class: IME | Handle: 526760
# Title: 'Default IME' | Class: IME | Handle: 264264
# Title: 'Default IME' | Class: IME | Handle: 8263216
# Title: 'Default IME' | Class: IME | Handle: 264100
# Title: 'Default IME' | Class: IME | Handle: 264056
# Title: 'Default IME' | Class: IME | Handle: 23534794
# Title: 'Default IME' | Class: IME | Handle: 19336760
# Title: 'Default IME' | Class: IME | Handle: 592314
# Title: 'Default IME' | Class: IME | Handle: 14421680
# Title: 'Default IME' | Class: IME | Handle: 1245556
# Title: 'Default IME' | Class: IME | Handle: 11408430
# Title: 'Default IME' | Class: IME | Handle: 591790
# Title: 'Default IME' | Class: IME | Handle: 134168
# Title: 'Default IME' | Class: IME | Handle: 12911630
# Title: 'M' | Class: MSCTFIME UI | Handle: 6554750
# Title: 'Default IME' | Class: IME | Handle: 22286408
# Title: 'Default IME' | Class: IME | Handle: 14359708
# Title: 'M' | Class: MSCTFIME UI | Handle: 21958346
# Title: 'Default IME' | Class: IME | Handle: 18357460
# Title: 'Default IME' | Class: IME | Handle: 1900592
# Title: 'Default IME' | Class: IME | Handle: 5709064
# Title: 'Default IME' | Class: IME | Handle: 16651046
# Title: 'M' | Class: MSCTFIME UI | Handle: 13897642
# Title: 'Default IME' | Class: IME | Handle: 1643038
# Title: 'Default IME' | Class: IME | Handle: 199298
# Title: 'Default IME' | Class: IME | Handle: 10820950
# Title: 'Default IME' | Class: IME | Handle: 199164
# Title: 'Default IME' | Class: IME | Handle: 1777952
# Title: 'M' | Class: MSCTFIME UI | Handle: 330234
# Title: 'Default IME' | Class: IME | Handle: 524544
# Title: 'Default IME' | Class: IME | Handle: 267294
# Title: 'Default IME' | Class: IME | Handle: 463986
# Title: 'Default IME' | Class: IME | Handle: 526630
# Title: 'Default IME' | Class: IME | Handle: 67806
# Title: 'Default IME' | Class: IME | Handle: 67624
# Title: 'Default IME' | Class: IME | Handle: 67620
# Title: 'Default IME' | Class: IME | Handle: 67616
# Title: 'Default IME' | Class: IME | Handle: 67612
# Title: 'Default IME' | Class: IME | Handle: 67608
# Title: 'Default IME' | Class: IME | Handle: 67604
# Title: 'Default IME' | Class: IME | Handle: 67600
# Title: 'Default IME' | Class: IME | Handle: 67596
# Title: 'Default IME' | Class: IME | Handle: 67592
# Title: 'Default IME' | Class: IME | Handle: 67588
# Title: 'Default IME' | Class: IME | Handle: 67584
# Title: 'Default IME' | Class: IME | Handle: 67578
# Title: 'Default IME' | Class: IME | Handle: 67572
# Title: 'Default IME' | Class: IME | Handle: 67568
# Title: 'Default IME' | Class: IME | Handle: 67564
# Title: 'Default IME' | Class: IME | Handle: 67560
# Title: 'Default IME' | Class: IME | Handle: 67556
# Title: 'Default IME' | Class: IME | Handle: 67552
# Title: 'Default IME' | Class: IME | Handle: 67548
# Title: 'Default IME' | Class: IME | Handle: 67544
# Title: 'Default IME' | Class: IME | Handle: 67540
# Title: 'Default IME' | Class: IME | Handle: 67536
# Title: 'Default IME' | Class: IME | Handle: 67532
# Title: 'Default IME' | Class: IME | Handle: 67528
# Title: 'Default IME' | Class: IME | Handle: 67524
# Title: 'Default IME' | Class: IME | Handle: 67520
# Title: 'Default IME' | Class: IME | Handle: 67516
# Title: 'Default IME' | Class: IME | Handle: 1181520
# Title: 'Default IME' | Class: IME | Handle: 395062
# Title: 'Default IME' | Class: IME | Handle: 67374
# Title: 'Default IME' | Class: IME | Handle: 262240
# Title: 'Default IME' | Class: IME | Handle: 196746
# Title: 'Default IME' | Class: IME | Handle: 131684
# Title: 'Default IME' | Class: IME | Handle: 66916
# Title: 'Default IME' | Class: IME | Handle: 131386
# Title: 'Default IME' | Class: IME | Handle: 66668
# Title: 'Default IME' | Class: IME | Handle: 65842
# Title: 'Default IME' | Class: IME | Handle: 65832
# Title: 'Default IME' | Class: IME | Handle: 131250
# Title: 'Default IME' | Class: IME | Handle: 131238
# Title: 'Default IME' | Class: IME | Handle: 199520
# Title: 'Default IME' | Class: IME | Handle: 3151206
# Title: 'Default IME' | Class: IME | Handle: 20257922
# Title: 'M' | Class: MSCTFIME UI | Handle: 10421458
# Title: 'Default IME' | Class: IME | Handle: 18874840

# %%
replace_dialog = Desktop(backend="win32").window(
    title="OPTV",
    class_name="#32770"
)
replace_dialog.wait("exists visible ready", timeout=10)
replace_dialog.set_focus()

no_btn = replace_dialog.child_window(
    title_re=".*No.*",
    class_name="Button"
)

no_btn.wait("enabled", timeout=10)
no_btn.click_input()

exit_dialog = dialog.child_window(title="&Cancel", class_name="Button")
exit_dialog.click_input()

# %%
las_dialog = Desktop(backend="win32").window(
    title="LAS 2.0 exportation for OPTV",
    class_name="#32770"
)
las_dialog.print_control_identifiers()
# Out:
# Control Identifiers:
#
# Dialog - 'LAS 2.0 exportation for OPTV'    (L792, T270, R1127, B762)
# ['LAS 2.0 exportation for OPTV', 'Dialog', 'LAS 2.0 exportation for OPTVDialog']
# child_window(title="LAS 2.0 exportation for OPTV", class_name="#32770")
#    |
#    | GroupBox - 'Selected Files'    (L807, T301, R1115, B386)
#    | ['Selected FilesGroupBox', 'Selected Files', 'GroupBox', 'GroupBox0', 'GroupBox1']
#    | child_window(title="Selected Files", class_name="Button")
#    |
#    | Static - '&Input file : '    (L839, T330, R889, B343)
#    | ['&Input file : Static', 'Static', '&Input file : ', 'Static0', 'Static1']
#    | child_window(title="&Input file : ", class_name="Static")
#    |
#    | Static - '*.hed'    (L899, T325, R1058, B346)
#    | ['Static2', '*.hed', '*.hedStatic']
#    | child_window(title="*.hed", class_name="Static")
#    |
#    | Button - '...'    (L1062, T325, R1086, B346)
#    | ['...Button', '...', 'Button', '...Button0', '...Button1', '...0', '...1', 'Button0', 'Button1']
#    | child_window(title="...", class_name="Button")
#    |
#    | Static - '&Output file :'    (L831, T355, R894, B368)
#    | ['Static3', '&Output file :', '&Output file :Static']
#    | child_window(title="&Output file :", class_name="Static")
#    |
#    | Static - '*.las'    (L899, T351, R1058, B371)
#    | ['Static4', '*.las', '*.lasStatic']
#    | child_window(title="*.las", class_name="Static")
#    |
#    | Button - '...'    (L1062, T350, R1086, B371)
#    | ['...Button2', '...2', 'Button2']
#    | child_window(title="...", class_name="Button")
#    |
#    | GroupBox - 'Configuration'    (L807, T390, R1115, B710)
#    | ['Configuration', 'GroupBox2', 'ConfigurationGroupBox']
#    | child_window(title="Configuration", class_name="Button")
#    |
#    | GroupBox - 'Export depth range'    (L816, T407, R1104, B490)
#    | ['Export depth range', 'GroupBox3', 'Export depth rangeGroupBox']
#    | child_window(title="Export depth range", class_name="Button")
#    |
#    | Static - '&From'    (L827, T431, R857, B444)
#    | ['Static5', '&FromStatic', '&From']
#    | child_window(title="&From", class_name="Static")
#    |
#    | Edit - ''    (L857, T428, R931, B448)
#    | ['&FromEdit', 'Edit', 'Edit0', 'Edit1']
#    | child_window(class_name="Edit")
#    |
#    | Static - '&To'    (L971, T431, R988, B444)
#    | ['Static6', '&To', '&ToStatic']
#    | child_window(title="&To", class_name="Static")
#    |
#    | Edit - ''    (L989, T428, R1063, B448)
#    | ['&ToEdit', 'Edit2']
#    | child_window(class_name="Edit")
#    |
#    | CheckBox - '&Reverse depth'    (L824, T463, R920, B478)
#    | ['&Reverse depthCheckBox', 'CheckBox', '&Reverse depth', 'CheckBox0', 'CheckBox1']
#    | child_window(title="&Reverse depth", class_name="Button")
#    |
#    | Static - 'Select sample interval :'    (L936, T463, R1047, B476)
#    | ['Static7', 'Select sample interval :Static', 'Select sample interval :']
#    | child_window(title="Select sample interval :", class_name="Static")
#    |
#    | ComboBox - '1cm'    (L1049, T459, R1099, B480)
#    | ['Select sample interval :ComboBox', 'ComboBox']
#    | child_window(title="1cm", class_name="ComboBox")
#    |    |
#    |    | Edit - '1cm'    (L1052, T462, R1079, B477)
#    |    | ['Select sample interval :Edit', 'Edit3']
#    |    | child_window(title="1cm", class_name="Edit")
#    |
#    | Edit - '1cm'    (L1052, T462, R1079, B477)
#    | ['Select sample interval :Edit', 'Edit3']
#    | child_window(title="1cm", class_name="Edit")
#    |
#    | GroupBox - 'Depth referred to camera'    (L815, T493, R1103, B534)
#    | ['Depth referred to cameraGroupBox', 'GroupBox4', 'Depth referred to camera']
#    | child_window(title="Depth referred to camera", class_name="Button")
#    |
#    | CheckBox - 'Inclination - Azimuth'    (L824, T511, R1016, B524)
#    | ['Inclination - Azimuth', 'Inclination - AzimuthCheckBox', 'CheckBox2']
#    | child_window(title="Inclination - Azimuth", class_name="Button")
#    |
#    | GroupBox - 'Depth referred to deviation sensor'    (L816, T538, R1104, B649)
#    | ['Depth referred to deviation sensor', 'Depth referred to deviation sensorGroupBox', 'GroupBox5']
#    | child_window(title="Depth referred to deviation sensor", class_name="Button")
#    |
#    | Static - 'Depth'    (L824, T559, R893, B574)
#    | ['Static8', 'Depth', 'DepthStatic']
#    | child_window(title="Depth", class_name="Static")
#    |
#    | CheckBox - 'Log Speed'    (L824, T582, R896, B595)
#    | ['Log SpeedCheckBox', 'Log Speed', 'CheckBox3']
#    | child_window(title="Log Speed", class_name="Button")
#    |
#    | CheckBox - 'Inclination'    (L824, T603, R896, B616)
#    | ['InclinationCheckBox', 'Inclination', 'CheckBox4']
#    | child_window(title="Inclination", class_name="Button")
#    |
#    | CheckBox - 'Azimuth'    (L926, T561, R998, B574)
#    | ['Azimuth', 'AzimuthCheckBox', 'CheckBox5']
#    | child_window(title="Azimuth", class_name="Button")
#    |
#    | CheckBox - 'HG Delta'    (L926, T582, R998, B595)
#    | ['HG DeltaCheckBox', 'HG Delta', 'CheckBox6']
#    | child_window(title="HG Delta", class_name="Button")
#    |
#    | CheckBox - 'Roll'    (L926, T603, R998, B616)
#    | ['Roll', 'RollCheckBox', 'CheckBox7']
#    | child_window(title="Roll", class_name="Button")
#    |
#    | CheckBox - 'Magn. Roll'    (L1016, T561, R1088, B574)
#    | ['CheckBox8', 'Magn. RollCheckBox', 'Magn. Roll']
#    | child_window(title="Magn. Roll", class_name="Button")
#    |
#    | CheckBox - 'Total Grav.'    (L1016, T582, R1088, B595)
#    | ['Total Grav.CheckBox', 'Total Grav.', 'CheckBox9']
#    | child_window(title="Total Grav.", class_name="Button")
#    |
#    | CheckBox - 'Total Mag.'    (L1016, T603, R1100, B616)
#    | ['Total Mag.', 'Total Mag.CheckBox', 'CheckBox10']
#    | child_window(title="Total Mag.", class_name="Button")
#    |
#    | CheckBox - 'Add deviation RAW data.'    (L824, T626, R1016, B639)
#    | ['Add deviation RAW data.', 'Add deviation RAW data.CheckBox', 'CheckBox11']
#    | child_window(title="Add deviation RAW data.", class_name="Button")
#    |
#    | GroupBox - 'Depth referred to gamma sensor'    (L816, T655, R1104, B696)
#    | ['Depth referred to gamma sensor', 'GroupBox6', 'Depth referred to gamma sensorGroupBox']
#    | child_window(title="Depth referred to gamma sensor", class_name="Button")
#    |
#    | CheckBox - 'Natural Gamma'    (L824, T673, R920, B686)
#    | ['Natural GammaCheckBox', 'Natural Gamma', 'CheckBox12']
#    | child_window(title="Natural Gamma", class_name="Button")
#    |
#    | Static - 'Infos'    (L809, T717, R992, B733)
#    | ['Static9', 'Infos', 'InfosStatic']
#    | child_window(title="Infos", class_name="Static")
#    |
#    | Progress - ''    (L809, T733, R991, B743)
#    | ['Progress', 'ConfigurationProgress']
#    | child_window(class_name="msctls_progress32")
#    |
#    | Button - '&Start'    (L1001, T723, R1052, B743)
#    | ['&StartButton', '&Start', 'Button3']
#    | child_window(title="&Start", class_name="Button")
#    |
#    | Button - '&Close'    (L1061, T723, R1112, B743)
#    | ['&CloseButton', '&Close', 'Button4']
#    | child_window(title="&Close", class_name="Button")
#    |
#    | Static - 'M'    (L936, T431, R954, B444)
#    | ['Static10', 'M', 'MStatic', 'M0', 'M1', 'MStatic0', 'MStatic1']
#    | child_window(title="M", class_name="Static")
#    |
#    | Static - 'M'    (L1067, T431, R1085, B444)
#    | ['Static11', 'M2', 'MStatic2']
#    | child_window(title="M", class_name="Static")

# %%
las_dialog = Desktop(backend="win32").window(
    title="LAS 2.0 exportation for OPTV",
    class_name="#32770"
)

las_dialog.descendants()[3].click_input()

open_dialog = Desktop(backend="win32").window(
    title="Open",
    class_name="#32770"
)

open_dialog.wait("exists visible ready", timeout=10)
open_dialog.set_focus()

pyperclip.copy(hed_file)
# Focus File name field
open_dialog.type_keys("%n")
time.sleep(0.2)

# Replace current *.hed with actual file path
open_dialog.type_keys("^a")
open_dialog.type_keys("^v")
time.sleep(0.2)

# Press Open
open_dialog.type_keys("{ENTER}")
# Out:
# <hwndwrapper.DialogWrapper - 'Open', Dialog, 7997530>

# %%
def ensure_checked(parent_window, title):
    checkbox = parent_window.child_window(
        title=title,
        class_name="Button"
    )

    checkbox.wait("exists enabled", timeout=10)

    state = checkbox.get_check_state()
    print(f"{title}: state before = {state}")

    # 0 = unchecked, 1 = checked, 2 = indeterminate
    if state == 0:
        checkbox.click_input()
        print(f"{title}: checked")

    else:
        print(f"{title}: already checked, no change")

    return checkbox.get_check_state()


targets = [
    "Inclination",
    "Azimuth",
    "Total Mag.",
    "Natural Gamma",
]

for title in targets:
    ensure_checked(las_dialog, title)
# Out:
# Inclination: state before = 1
# Inclination: already checked, no change
# Azimuth: state before = 1
# Azimuth: already checked, no change
# Total Mag.: state before = 1
# Total Mag.: already checked, no change
# Natural Gamma: state before = 1
# Natural Gamma: already checked, no change

# %%
las_export = las_dialog.child_window(

    title = '&Start',
    class_name = "Button"
)


las_export.click_input()

# if there is existing file, skipped. if not go on generate.
replace_dialog = Desktop(backend="win32").window(
    title="OPTV",
    class_name="#32770"
)
replace_dialog.wait("exists visible ready", timeout=10)
replace_dialog.set_focus()

no_btn = replace_dialog.child_window(
    title_re=".*No.*",
    class_name="Button"
)
no_btn.wait("enabled", timeout=10)
no_btn.click_input()
replace_dialog2 = Desktop(backend="win32").window(
    title="OPTV",
    class_name="#32770"
)
replace_dialog2.set_focus()

ok_btn = replace_dialog2.child_window(
    title_re=".*OK.*",
    class_name="Button"
)

ok_btn.wait("enabled", timeout=10)
ok_btn.click_input()

exit_dialog = las_dialog.child_window(title="&Close", class_name="Button")
exit_dialog.click_input() # leave if only one hole

# %%
hed_file = r"C:\2026_RTIO\Hope Downs\Sent\GR26HD40003\ATV\GR26HD40003_OUTRUN_H.hed"


app = Application(backend="uia").start(BHTV_PATH)

app.BHTV.OK.click()

# switch to the window
main = app.window(title_re=".*BHTV Acquisition.*")
main.set_focus()


main.type_keys("%f")       # Alt + F, open File menu
time.sleep(0.1)

main.type_keys("x") # move to Export
time.sleep(0.1)

main.type_keys("l")  # open Export submenu
time.sleep(0.1)


las_dialog = Desktop(backend="win32").window(
    title="LAS 2.0 exportation for BHTV",
    class_name="#32770"
)

las_dialog.descendants()[3].click_input()

open_dialog = Desktop(backend="win32").window(
    title="Open",
    class_name="#32770"
)

open_dialog.wait("exists visible ready", timeout=10)
open_dialog.set_focus()

pyperclip.copy(hed_file)
# Focus File name field
open_dialog.type_keys("%n")
time.sleep(0.2)

# Replace current *.hed with actual file path
open_dialog.type_keys("^a")
open_dialog.type_keys("^v")
time.sleep(0.2)

# Press Open
open_dialog.type_keys("{ENTER}")

targets = [
    "Inclination",
    "Azimuth",
    "Total Mag.",
    "Natural Gamma",
]

for title in targets:
    ensure_checked(las_dialog, title)


las_export = las_dialog.child_window(

    title = '&Start',
    class_name = "Button"
)


las_export.click_input()

# if there is existing file, skipped. if not go on generate.
replace_dialog = Desktop(backend="win32").window(
    title="BHTV",
    class_name="#32770"
)
replace_dialog.wait("exists visible ready", timeout=10)
replace_dialog.set_focus()

no_btn = replace_dialog.child_window(
    title_re=".*No.*",
    class_name="Button"
)
no_btn.wait("enabled", timeout=10)
no_btn.click_input()
replace_dialog2 = Desktop(backend="win32").window(
    title="BHTV",
    class_name="#32770"
)

replace_dialog2.set_focus()

ok_btn = replace_dialog2.child_window(
    title_re=".*OK.*",
    class_name="Button"
)

ok_btn.wait("enabled", timeout=10)
ok_btn.click_input()

exit_dialog = las_dialog.child_window(title="&Close", class_name="Button")
exit_dialog.click_input() # leave if only one hole
# Out:
# Inclination: state before = 1
# Inclination: already checked, no change
# Azimuth: state before = 1
# Azimuth: already checked, no change
# Total Mag.: state before = 1
# Total Mag.: already checked, no change
# Natural Gamma: state before = 1
# Natural Gamma: already checked, no change

# %% [markdown]
# also in organize_hole_files.py. I want the interface and backend that are flexible, searching files in selected directory. if there is zip files unzip them, then sort the file according to their hole id (can be read in hed file). The folder structure can be toggled, now I want: Hole id/ under it there are GPX, OTV and ATV. related files can (OTV goes to OTV) (ATV goes to ATV)
